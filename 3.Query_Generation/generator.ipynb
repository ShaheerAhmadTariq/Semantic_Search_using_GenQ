# %%
from llm import generate_queries
import pandas as pd
from tqdm import tqdm

df = pd.read_csv('../Data_ETL/dataset.csv', dtype=object)
df.head()
# Out:
#   Unnamed: 0                        id  \
# 0          0  6531349b011af268d2c45974
# 1          1  653181158a587da37ea6e356
# 2          2  6530f9604f267515c92d16ce
# 3          3  6530f9604f267515c92d16ce
# 4          4  6530f9604f267515c92d16ce
#
#                                             document query1 query2 query3  \
# 0                                          ertyuiop[    NaN    NaN    NaN
# 1                                             qwerty    NaN    NaN    NaN
# 2  Lorem ipsum samir dil olr Lorem ipsum samir di...    NaN    NaN    NaN
# 3  olr Lorem ipsum samir dil olr Lorem ipsum sami...    NaN    NaN    NaN
# 4  dil olr Lorem ipsum samir dil olr Lorem ipsum ...    NaN    NaN    NaN
#
#   query4 query5
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN

# %%
# Iterate over df rows with a status bar from tqdm
for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Processing Documents"):
    document_str = row['document']
    try:
        queries_list = generate_queries(document_str)  # Your function to generate queries
        count = 1
        for query in queries_list:
            if count > 5:
                break
            df.at[index, f"query{count}"] = query
            count += 1
    except Exception as e:
        print(f"Error processing document ID {row['id']}: {e}")

# %%
df.to_csv('./dataset_Q_D.csv', index=False)
